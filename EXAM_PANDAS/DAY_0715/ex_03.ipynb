# %%
import pandas as pd

DIR = '../../Data/'
# 지하철 시간대별 이용현황
df = pd.read_excel(DIR+'subway.xls', sheet_name='지하철 시간대별 이용현황', header=[0, 1])
df
# Out:
#                    사용월                호선명                역ID  \
#     Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
# 0              2022-06                1호선                150
# 1              2022-06                1호선                151
# 2              2022-06                1호선                152
# 3              2022-06                1호선                153
# 4              2022-06                1호선                154
# ..                 ...                ...                ...
# 610            2022-06                신림선               4407
# 611            2022-06                신림선               4408
# 612            2022-06                신림선               4409
# 613            2022-06                신림선               4410
# 614            2022-06                신림선               4411
#
#                   지하철역 04:00:00~04:59:59     05:00:00~05:59:59         \
#     Unnamed: 3_level_1                승차  하차                승차     하차
# 0                  서울역               646  24             8,433  7,694
# 1                   시청               271   7             3,133  4,802
# 2                   종각                91   9             4,007  3,960
# 3                 종로3가               190  12             3,882  3,261
# 4                 종로5가                34   0             1,730  3,909
# ..                 ...               ...  ..               ...    ...
# 610                 당곡                 0   0             1,061    118
# 611                 신림                 2   1               651    153
# 612                 서원                 2   1             1,287    151
# 613            서울대벤처타운                10   3             3,314    166
# 614           관악산(서울대)                 2   5               475    742
#
#     06:00:00~06:59:59          ... 23:00:00~23:59:59 00:00:00~00:59:59         \
#                    승차      하차  ...                하차                승차     하차
# 0              12,608  46,963  ...            15,480               158  1,332
# 1               3,321  23,621  ...             2,938                72    422
# 2               3,682  22,533  ...             3,590               315    394
# 3               3,570  14,038  ...             4,119               310    843
# 4               2,986  16,406  ...             2,628                98    668
# ..                ...     ...  ...               ...               ...    ...
# 610             2,650     704  ...             2,710               156    637
# 611               853     488  ...             2,023               177    629
# 612             2,552     513  ...             3,281                68    782
# 613             5,162   1,676  ...             7,279               180  1,974
# 614             1,258   1,712  ...             1,224                90    412
#
#     01:00:00~01:59:59     02:00:00~02:59:59    03:00:00~03:59:59     \
#                    승차  하차                승차 하차                승차 하차
# 0                   1   4                 0  1                 0  0
# 1                   0   2                 0  0                 0  0
# 2                   0   1                 0  0                 0  0
# 3                   3   3                 0  0                 0  0
# 4                   0   0                 0  0                 0  0
# ..                ...  ..               ... ..               ... ..
# 610                 0   0                 0  0                 0  0
# 611                 0   1                 0  0                 0  0
# 612                 2   2                 0  0                 0  0
# 613                 1  40                 0  0                 0  0
# 614                 1  33                 0  0                 0  0
#
#                     작업일시
#      Unnamed: 52_level_1
# 0    2022-07-03 09:48:05
# 1    2022-07-03 09:48:05
# 2    2022-07-03 09:48:05
# 3    2022-07-03 09:48:05
# 4    2022-07-03 09:48:05
# ..                   ...
# 610  2022-07-03 09:48:05
# 611  2022-07-03 09:48:05
# 612  2022-07-03 09:48:05
# 613  2022-07-03 09:48:05
# 614  2022-07-03 09:48:05
#
# [615 rows x 53 columns]

# %%
df.columns
# Out:
# MultiIndex([(              '사용월',  'Unnamed: 0_level_1'),
#             (              '호선명',  'Unnamed: 1_level_1'),
#             (              '역ID',  'Unnamed: 2_level_1'),
#             (             '지하철역',  'Unnamed: 3_level_1'),
#             ('04:00:00~04:59:59',                  '승차'),
#             ('04:00:00~04:59:59',                  '하차'),
#             ('05:00:00~05:59:59',                  '승차'),
#             ('05:00:00~05:59:59',                  '하차'),
#             ('06:00:00~06:59:59',                  '승차'),
#             ('06:00:00~06:59:59',                  '하차'),
#             ('07:00:00~07:59:59',                  '승차'),
#             ('07:00:00~07:59:59',                  '하차'),
#             ('08:00:00~08:59:59',                  '승차'),
#             ('08:00:00~08:59:59',                  '하차'),
#             ('09:00:00~09:59:59',                  '승차'),
#             ('09:00:00~09:59:59',                  '하차'),
#             ('10:00:00~10:59:59',                  '승차'),
#             ('10:00:00~10:59:59',                  '하차'),
#             ('11:00:00~11:59:59',                  '승차'),
#             ('11:00:00~11:59:59',                  '하차'),
#             ('12:00:00~12:59:59',                  '승차'),
#             ('12:00:00~12:59:59',                  '하차'),
#             ('13:00:00~13:59:59',                  '승차'),
#             ('13:00:00~13:59:59',                  '하차'),
#             ('14:00:00~14:59:59',                  '승차'),
#             ('14:00:00~14:59:59',                  '하차'),
#             ('15:00:00~15:59:59',                  '승차'),
#             ('15:00:00~15:59:59',                  '하차'),
#             ('16:00:00~16:59:59',                  '승차'),
#             ('16:00:00~16:59:59',                  '하차'),
#             ('17:00:00~17:59:59',                  '승차'),
#             ('17:00:00~17:59:59',                  '하차'),
#             ('18:00:00~18:59:59',                  '승차'),
#             ('18:00:00~18:59:59',                  '하차'),
#             ('19:00:00~19:59:59',                  '승차'),
#             ('19:00:00~19:59:59',                  '하차'),
#             ('20:00:00~20:59:59',                  '승차'),
#             ('20:00:00~20:59:59',                  '하차'),
#             ('21:00:00~21:59:59',                  '승차'),
#             ('21:00:00~21:59:59',                  '하차'),
#             ('22:00:00~22:59:59',                  '승차'),
#             ('22:00:00~22:59:59',                  '하차'),
#             ('23:00:00~23:59:59',                  '승차'),
#             ('23:00:00~23:59:59',                  '하차'),
#             ('00:00:00~00:59:59',                  '승차'),
#             ('00:00:00~00:59:59',                  '하차'),
#             ('01:00:00~01:59:59',                  '승차'),
#             ('01:00:00~01:59:59',                  '하차'),
#             ('02:00:00~02:59:59',                  '승차'),
#             ('02:00:00~02:59:59',                  '하차'),
#             ('03:00:00~03:59:59',                  '승차'),
#             ('03:00:00~03:59:59',                  '하차'),
#             (             '작업일시', 'Unnamed: 52_level_1')],
#            )

# %%
df[('호선명', 'Unnamed: 1_level_1')] # 멀티인덱스 >> 튜플형태
# Out:
# 0      1호선
# 1      1호선
# 2      1호선
# 3      1호선
# 4      1호선
#       ...
# 610    신림선
# 611    신림선
# 612    신림선
# 613    신림선
# 614    신림선
# Name: (호선명, Unnamed: 1_level_1), Length: 615, dtype: object

# %%
df[('지하철역', 'Unnamed: 3_level_1')]
# Out:
# 0           서울역
# 1            시청
# 2            종각
# 3          종로3가
# 4          종로5가
#          ...
# 610          당곡
# 611          신림
# 612          서원
# 613     서울대벤처타운
# 614    관악산(서울대)
# Name: (지하철역, Unnamed: 3_level_1), Length: 615, dtype: object

# %%
commute_time_df = df.iloc[:, [1, 3, 10, 12, 14]]
commute_time_df.head()
# Out:
#                  호선명               지하철역 07:00:00~07:59:59 08:00:00~08:59:59  \
#   Unnamed: 1_level_1 Unnamed: 3_level_1                승차                승차
# 0                1호선                서울역            39,233            65,106
# 1                1호선                 시청             6,647             8,294
# 2                1호선                 종각             5,814             9,612
# 3                1호선               종로3가             4,746             8,589
# 4                1호선               종로5가             5,020             8,550
#
#   09:00:00~09:59:59
#                  승차
# 0            54,833
# 1             9,211
# 2            11,847
# 3            13,179
# 4            11,925

# %%
commute_time_df.dtypes
# Out:
# 호선명                Unnamed: 1_level_1    object
# 지하철역               Unnamed: 3_level_1    object
# 07:00:00~07:59:59  승차                    object
# 08:00:00~08:59:59  승차                    object
# 09:00:00~09:59:59  승차                    object
# dtype: object

# %%
commute_time_df[('07:00:00~07:59:59', '승차')] = commute_time_df[('07:00:00~07:59:59', '승차')].apply(lambda x : x.replace(',',''))
commute_time_df[('08:00:00~08:59:59', '승차')] = commute_time_df[('08:00:00~08:59:59', '승차')].apply(lambda x : x.replace(',',''))
commute_time_df[('09:00:00~09:59:59', '승차')] = commute_time_df[('09:00:00~09:59:59', '승차')].apply(lambda x : x.replace(',',''))
commute_time_df
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_2260\3642604935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commute_time_df[('07:00:00~07:59:59', '승차')] = commute_time_df[('07:00:00~07:59:59', '승차')].apply(lambda x : x.replace(',',''))
# C:\Users\ss\AppData\Local\Temp\ipykernel_2260\3642604935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commute_time_df[('08:00:00~08:59:59', '승차')] = commute_time_df[('08:00:00~08:59:59', '승차')].apply(lambda x : x.replace(',',''))
# C:\Users\ss\AppData\Local\Temp\ipykernel_2260\3642604935.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commute_time_df[('09:00:00~09:59:59', '승차')] = commute_time_df[('09:00:00~09:59:59', '승차')].apply(lambda x : x.replace(',',''))
#                    호선명               지하철역 07:00:00~07:59:59 08:00:00~08:59:59  \
#     Unnamed: 1_level_1 Unnamed: 3_level_1                승차                승차
# 0                  1호선                서울역             39233             65106
# 1                  1호선                 시청              6647              8294
# 2                  1호선                 종각              5814              9612
# 3                  1호선               종로3가              4746              8589
# 4                  1호선               종로5가              5020              8550
# ..                 ...                ...               ...               ...
# 610                신림선                 당곡              7708             11603
# 611                신림선                 신림              3099              5402
# 612                신림선                 서원              8427             12646
# 613                신림선            서울대벤처타운             16194             22232
# 614                신림선           관악산(서울대)              4086              4382
#
#     09:00:00~09:59:59
#                    승차
# 0               54833
# 1                9211
# 2               11847
# 3               13179
# 4               11925
# ..                ...
# 610              6862
# 611              2941
# 612              7590
# 613             13280
# 614              3446
#
# [615 rows x 5 columns]

# %%
commute_time_df = commute_time_df.astype({('07:00:00~07:59:59', '승차'):'int64'})
commute_time_df = commute_time_df.astype({('08:00:00~08:59:59', '승차'):'int64'})
commute_time_df = commute_time_df.astype({('09:00:00~09:59:59', '승차'):'int64'})
commute_time_df.dtypes
# Out:
# 호선명                Unnamed: 1_level_1    object
# 지하철역               Unnamed: 3_level_1    object
# 07:00:00~07:59:59  승차                     int64
# 08:00:00~08:59:59  승차                     int64
# 09:00:00~09:59:59  승차                     int64
# dtype: object

# %%
row_sum_df = commute_time_df.sum(axis=1)
passenger_number_list = row_sum_df.to_list()
passenger_number_list
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_2260\530537507.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   row_sum_df = commute_time_df.sum(axis=1)
# [159172,
#  24152,
#  27273,
#  26514,
#  25495,
#  50361,
#  62758,
#  74828,
#  111867,
#  24621,
#  20882,
#  40110,
#  27510,
#  20036,
#  26595,
#  96726,
#  135277,
#  98541,
#  19338,
#  60455,
#  76233,
#  200286,
#  240949,
#  266708,
#  109806,
#  379023,
#  169326,
#  52234,
#  52803,
#  81644,
#  61350,
#  148582,
#  88819,
#  68114,
#  78963,
#  249022,
#  279179,
#  408769,
#  266976,
#  638753,
#  294686,
#  415838,
#  218013,
#  349991,
#  114408,
#  109760,
#  128942,
#  132499,
#  188177,
#  121187,
#  76589,
#  88415,
#  50503,
#  27262,
#  21936,
#  16394,
#  8742,
#  79681,
#  118347,
#  18410,
#  58209,
#  201246,
#  357596,
#  142702,
#  184695,
#  173199,
#  39698,
#  46458,
#  53515,
#  25297,
#  7498,
#  10425,
#  0,
#  20618,
#  89594,
#  82619,
#  72729,
#  58894,
#  41157,
#  36729,
#  114064,
#  31908,
#  103855,
#  108906,
#  50767,
#  27239,
#  62964,
#  11566,
#  78547,
#  61663,
#  104872,
#  56395,
#  61454,
#  68477,
#  94642,
#  198012,
#  137508,
#  214781,
#  317323,
#  304253,
#  128426,
#  248467,
#  216622,
#  129003,
#  90113,
#  60715,
#  25058,
#  23845,
#  36870,
#  23293,
#  22056,
#  39135,
#  61052,
#  23468,
#  41479,
#  40167,
#  7028,
#  141809,
#  220773,
#  8678,
#  44985,
#  40939,
#  89430,
#  52871,
#  81527,
#  135809,
#  27958,
#  71596,
#  102938,
#  41949,
#  114108,
#  94555,
#  77757,
#  202574,
#  60475,
#  227461,
#  46996,
#  71902,
#  145698,
#  91486,
#  182940,
#  112334,
#  30115,
#  124330,
#  24997,
#  28749,
#  67606,
#  7730,
#  34096,
#  43028,
#  23039,
#  79638,
#  20049,
#  5248,
#  39788,
#  33672,
#  60785,
#  16601,
#  28599,
#  226053,
#  128714,
#  293762,
#  269210,
#  245852,
#  205386,
#  67803,
#  144013,
#  153657,
#  91578,
#  90330,
#  14248,
#  63916,
#  81211,
#  92318,
#  55483,
#  18872,
#  58960,
#  99542,
#  41383,
#  25779,
#  9852,
#  14820,
#  206,
#  19894,
#  91590,
#  94695,
#  55525,
#  95318,
#  72190,
#  72440,
#  64246,
#  52028,
#  1,
#  84549,
#  51415,
#  57250,
#  71317,
#  133346,
#  119828,
#  59630,
#  41674,
#  73511,
#  32862,
#  47900,
#  60757,
#  24454,
#  12130,
#  16799,
#  13143,
#  132718,
#  49594,
#  43392,
#  166087,
#  75251,
#  131670,
#  68523,
#  47630,
#  62612,
#  17263,
#  47132,
#  72084,
#  46182,
#  53796,
#  7161,
#  4014,
#  67519,
#  55535,
#  187884,
#  125719,
#  203763,
#  17196,
#  63776,
#  32851,
#  12800,
#  25321,
#  42296,
#  86314,
#  4,
#  59883,
#  48796,
#  20161,
#  25735,
#  17423,
#  58575,
#  145569,
#  165774,
#  158005,
#  102111,
#  57757,
#  85454,
#  81118,
#  85688,
#  40566,
#  24836,
#  102348,
#  55996,
#  49116,
#  90526,
#  53309,
#  45017,
#  47723,
#  124007,
#  51766,
#  76098,
#  24541,
#  115153,
#  0,
#  201827,
#  115468,
#  137490,
#  21727,
#  60164,
#  44482,
#  26575,
#  72376,
#  127692,
#  174849,
#  60172,
#  59691,
#  71168,
#  30729,
#  137443,
#  128776,
#  4536,
#  56888,
#  27096,
#  4477,
#  4961,
#  15886,
#  1364,
#  5725,
#  4659,
#  2910,
#  19301,
#  3189,
#  11832,
#  625,
#  7246,
#  17533,
#  16775,
#  6913,
#  9237,
#  27078,
#  6683,
#  1855,
#  17552,
#  10701,
#  56818,
#  11358,
#  11131,
#  44456,
#  87075,
#  40796,
#  4658,
#  72612,
#  55421,
#  100495,
#  81447,
#  71507,
#  73878,
#  42422,
#  51217,
#  7256,
#  7137,
#  42083,
#  23,
#  8610,
#  13637,
#  4715,
#  26866,
#  6,
#  0,
#  19621,
#  33924,
#  30140,
#  41287,
#  25667,
#  13016,
#  61248,
#  19596,
#  37692,
#  6493,
#  13422,
#  1984,
#  10708,
#  766,
#  359,
#  1890,
#  1425,
#  15590,
#  6710,
#  32542,
#  26510,
#  4732,
#  3749,
#  55231,
#  363,
#  27049,
#  39171,
#  37651,
#  20765,
#  4344,
#  38959,
#  36476,
#  23209,
#  49816,
#  31144,
#  7905,
#  5629,
#  11392,
#  10316,
#  32850,
#  101928,
#  37918,
#  18649,
#  14447,
#  20075,
#  15591,
#  3026,
#  17082,
#  65257,
#  53005,
#  19065,
#  56771,
#  61340,
#  72095,
#  142480,
#  326026,
#  355738,
#  178265,
#  169344,
#  137778,
#  64977,
#  21858,
#  67100,
#  43375,
#  33248,
#  18112,
#  76939,
#  66296,
#  53796,
#  19922,
#  56917,
#  32310,
#  12194,
#  6430,
#  4267,
#  24312,
#  64291,
#  94286,
#  19567,
#  45666,
#  161050,
#  158581,
#  99089,
#  131803,
#  112985,
#  85112,
#  154522,
#  62738,
#  95037,
#  85734,
#  70587,
#  168404,
#  65567,
#  30606,
#  47384,
#  20808,
#  57624,
#  113580,
#  88345,
#  49846,
#  159796,
#  28301,
#  62581,
#  52116,
#  202111,
#  40853,
#  28783,
#  32940,
#  6,
#  85722,
#  144692,
#  113281,
#  121931,
#  22469,
#  125313,
#  86368,
#  49027,
#  31909,
#  60575,
#  48625,
#  69472,
#  57845,
#  29643,
#  17787,
#  33815,
#  11993,
#  16733,
#  17427,
#  22217,
#  25787,
#  34226,
#  39440,
#  68758,
#  30109,
#  61354,
#  108390,
#  66750,
#  98884,
#  128647,
#  51994,
#  136508,
#  103101,
#  1,
#  27859,
#  110379,
#  124595,
#  153051,
#  104851,
#  155878,
#  175917,
#  101506,
#  65554,
#  104781,
#  107087,
#  161496,
#  166618,
#  163982,
#  68350,
#  103427,
#  129096,
#  75969,
#  46253,
#  72074,
#  37078,
#  24780,
#  30110,
#  34122,
#  26508,
#  52319,
#  64910,
#  98140,
#  123569,
#  114957,
#  103586,
#  87291,
#  170047,
#  65242,
#  120317,
#  53856,
#  88201,
#  65592,
#  211290,
#  215746,
#  139115,
#  121703,
#  0,
#  0,
#  0,
#  1,
#  228845,
#  124212,
#  93171,
#  38641,
#  30192,
#  51668,
#  76819,
#  33134,
#  70507,
#  129538,
#  84430,
#  59272,
#  151273,
#  101389,
#  35808,
#  49736,
#  26389,
#  44345,
#  25964,
#  26227,
#  26760,
#  69689,
#  73760,
#  76273,
#  190574,
#  55611,
#  121307,
#  206338,
#  50504,
#  58265,
#  146706,
#  16521,
#  30449,
#  15980,
#  199974,
#  49577,
#  52250,
#  16982,
#  4862,
#  18887,
#  55224,
#  31559,
#  105001,
#  34536,
#  14837,
#  31165,
#  49104,
#  36344,
#  38158,
#  139343,
#  73123,
#  65493,
#  60585,
#  6033,
#  34444,
#  16187,
#  28681,
#  25779,
#  26289,
#  18326,
#  27886,
#  26857,
#  70503,
#  60337,
#  76673,
#  40344,
#  20770,
#  46723,
#  10021,
#  109499,
#  23833,
#  26993,
#  24645,
#  45775,
#  35316,
#  19378,
#  22617,
#  73004,
#  59621,
#  46364,
#  15368,
#  8787,
#  5364,
#  4368,
#  11806,
#  15978,
#  16823,
#  10765,
#  16253,
#  26173,
#  11442,
#  28663,
#  51706,
#  11914]

# %%
row_sum_df
# Out:
# 0      159172
# 1       24152
# 2       27273
# 3       26514
# 4       25495
#         ...
# 610     26173
# 611     11442
# 612     28663
# 613     51706
# 614     11914
# Length: 615, dtype: int64

# %%
max_number = row_sum_df.max(axis=0) # 해당 열에서 최대값 찾기
max_number
# Out:
# 638753

# %%
max_index = row_sum_df.idxmax() # 최대값 인덱스 : idxmax()
max_line, max_station = df.iloc[max_index, [1,3]]

print(f'출근 시간대 최대 승차 인원역 : {max_line} {max_station} {max_number:,}명')
# Out:
# 출근 시간대 최대 승차 인원역 : 2호선 신림 638,753명

# %%
import matplotlib.pyplot as plt

passenger_number_list.sort(reverse=True)
plt.figure(dpi=100)
plt.bar(range(len(passenger_number_list)), passenger_number_list)
plt.show()
