# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import font_manager as fm, rc

font_path='../../Font/malgun.ttf'
font_name=fm.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)
DIR = '../../Data/'
FILE1 = DIR+'애니(남자).xlsx'
FILE2 = DIR+'애니(여자).xlsx'
FILE3 = DIR+'영화(남자).xlsx'
FILE4 = DIR+'영화(여자).xlsx'
FILE5 = DIR+'드라마(남자).xlsx'
FILE6 = DIR+'드라마(여자).xlsx'
FILE7 = DIR+'예능(남자).xlsx'
FILE8 = DIR+'예능(여자).xlsx'

# %%
FILEAGE1 = DIR+'18세이하.xlsx'
FILEAGE2 = DIR+'20대.xlsx'
FILEAGE3 = DIR+'30대.xlsx'
FILEAGE4 = DIR+'40대.xlsx'
FILEAGE5 = DIR+'50대.xlsx'
FILEAGE6 = DIR+'60세이상.xlsx'

# %%
df1 = pd.read_excel(FILE1, skiprows=6)         # 디즈니+ 데이터를 크게 장르별 연령별로 나눔
df2 = pd.read_excel(FILE2, skiprows=6)
df3 = pd.read_excel(FILE3, skiprows=6)
df4 = pd.read_excel(FILE4, skiprows=6)
df5 = pd.read_excel(FILE5, skiprows=6)
df6 = pd.read_excel(FILE6, skiprows=6)
df7 = pd.read_excel(FILE7, skiprows=6)
df8 = pd.read_excel(FILE8, skiprows=6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
ageDF1 = pd.read_excel(FILEAGE1, skiprows=6)
ageDF2 = pd.read_excel(FILEAGE2, skiprows=6)
ageDF3 = pd.read_excel(FILEAGE3, skiprows=6)
ageDF4 = pd.read_excel(FILEAGE4, skiprows=6)
ageDF5 = pd.read_excel(FILEAGE5, skiprows=6)
ageDF6 = pd.read_excel(FILEAGE6, skiprows=6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df1.rename(columns={'디즈니플러스':'Ani(M)'}, inplace=True)
df2.rename(columns={'디즈니플러스':'Ani(F)'}, inplace=True)
df3.rename(columns={'디즈니플러스':'Movie(M)'}, inplace=True)
df4.rename(columns={'디즈니플러스':'Movie(F)'}, inplace=True)
df5.rename(columns={'디즈니플러스':'Drama(M)'}, inplace=True)
df6.rename(columns={'디즈니플러스':'Drama(F)'}, inplace=True)
df7.rename(columns={'디즈니플러스':'Enter(M)'}, inplace=True)
df8.rename(columns={'디즈니플러스':'Enter(F)'}, inplace=True)

# %%
allDF = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8], axis=1, join='inner') # concat으로 연결

# %%
allDF = allDF.loc[:,~allDF.T.duplicated()] # 중복 컬럼 제거

# %%
allDF['날짜'] = pd.to_datetime(allDF['날짜'])

# %%
allDF['Year'] = allDF['날짜'].dt.year               # 불러온 각각의 데이터를 합치고 
allDF['Month'] = allDF['날짜'].dt.month
allDF['Day'] = allDF['날짜'].dt.day
allDF
# Out:
#              날짜   Ani(M)   Ani(F)  Movie(M)  Movie(F)  Drama(M)  Drama(F)  \
# 0    2019-01-01  1.06476  1.05955  71.25644  70.00321  61.61217  67.50990
# 1    2019-01-02  1.05674  0.98758  40.62377  40.73579  60.82245  61.99939
# 2    2019-01-03  0.82213  1.06955  38.65465  39.52675  48.11479  50.99359
# 3    2019-01-04  0.76799  0.84164  46.80493  45.40184  42.07155  48.36025
# 4    2019-01-05  1.03870  0.85564  65.74567  57.49518  44.94149  45.57756
# ...         ...      ...      ...       ...       ...       ...       ...
# 1272 2022-06-26  0.62963  0.73369  36.72071  35.86458  50.64766  62.22797
# 1273 2022-06-27  0.46721  0.57575  26.18198  27.31951  55.05369  71.53916
# 1274 2022-06-28  0.50130  0.57975  24.92809  26.27182  50.87879  63.31606
# 1275 2022-06-29  0.49729  0.57775  28.48974  30.55385  53.82578  67.93355
# 1276 2022-06-30  0.45317  0.54177  27.92556  30.65679  50.61877  66.53154
#
#       Enter(M)  Enter(F)  Year  Month  Day
# ...

# %%
allDF.iloc[allDF['날짜']]

# %%
allDF_1 = allDF.iloc[:,1:-1]
groupDF = allDF_1.groupby(['Year','Month']).mean()
groupDF                                                    # year, month 기준 그룹화 후 평균값 계산
# Out:
#               Ani(M)    Ani(F)   Movie(M)   Movie(F)   Drama(M)   Drama(F)  \
# Year Month
# 2019 1      0.809196  0.814685  49.025494  46.923293  45.053794  49.202244
#      2      0.821417  0.866345  50.352435  46.737659  52.197506  53.227126
#      3      0.751303  0.757354  44.518411  39.436285  49.079411  47.404405
#      4      0.745466  0.657719  39.557133  35.790205  46.787847  44.881941
#      5      3.984807  3.893005  37.310034  34.173293  46.949483  48.172563
#      6      0.818322  0.696969  39.696799  34.198324  44.803289  47.232750
#      7      0.835069  0.752647  44.266401  43.088656  54.620771  56.952537
#      8      0.720319  0.632439  51.088454  47.592369  46.914687  49.097536
#      9      0.614592  0.586149  55.487148  48.614002  49.718459  52.281921
#      10     0.696128  0.646175  46.849734  42.268709  53.054857  59.595712
#      11     0.722608  0.741219  45.626997  39.990529  47.527482  49.679971
# ...

# %%
recentDF.iloc[:,0:2].plot(figsize=(15,6)) #애니 성별
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
recentDF.iloc[:,2:4].plot(figsize=(15,6)) # 영화 성별 : 영화에서는 남녀간 수치가 비슷한데 디즈니+ 의 주력인 마블이 남성에게 더 인기
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
recentDF.iloc[:,4:6].plot(figsize=(15,6)) # 드라마 성별 드라마 컨텐츠에 있어 여성 비율이 더 높은데 마블 디즈니가 주컨텐츠 인데도 불구하고
                                         # 찾아보니 드라마 장르의 많은 부분이 멜로,로멘스였다.
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
recentDF.iloc[:,6:8].plot(figsize=(15,6)) # 예능 성별
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
df2019 = allDF[allDF['날짜'].dt.year == 2019].set_index('날짜')
df2020 = allDF[allDF['날짜'].dt.year == 2020].set_index('날짜')
df2021 = allDF[allDF['날짜'].dt.year == 2021].set_index('날짜')
df2022 = allDF[allDF['날짜'].dt.year == 2022].set_index('날짜')

# %%
df2019_1 = df2019.reset_index().iloc[:,1:-1]     
df2020_1 = df2020.reset_index().iloc[:,1:-1]
df2021_1 = df2021.reset_index().iloc[:,1:-1]
df2022_1 = df2022.reset_index().iloc[:,1:-1]

# %%
df2019group = df2019_1.groupby(['Year','Month']).mean()    # 년도, 월별 그룹화 후 평균
df2020group = df2020_1.groupby(['Year','Month']).mean()
df2021group = df2021_1.groupby(['Year','Month']).mean()
df2022group = df2022_1.groupby(['Year','Month']).mean()

# %%
recentAniDF1 = groupDF.iloc[:,0:1]*2850*0.22   # 카테고리 별 건수 계산
recentAniDF2 = groupDF.iloc[:,1:2]*2850*0.78

# %%
recentMovDF1 = groupDF.iloc[:,2:3]*452*0.46
recentMovDF2 = groupDF.iloc[:,3:4]*452*0.54

# %%
recentDraDF1 = groupDF.iloc[:,4:5]*136*0.37
recentDraDF2 = groupDF.iloc[:,5:6]*136*0.63

# %%
recentEntDF1 = groupDF.iloc[:,6:7]*14*0.35
recentEntDF2 = groupDF.iloc[:,7:8]*14*0.65

# %%
recentDF = pd.concat([recentAniDF1,recentAniDF2,recentMovDF1,recentMovDF2,recentDraDF1,recentDraDF2,recentEntDF1,recentEntDF2],axis=1)
recentDF.plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %% [markdown]
# ### 디즈니+ 2019년 11월 서비스 시작했는데 기대감과 코로나 시기와 맞물려  대부분의 장르의 검색량
# ### 2019년 전후로 해서 가장 많은 수치를 보여줌

# %%
ageDF1.rename(columns={'디즈니플러스':'18세이하'}, inplace=True)
ageDF2.rename(columns={'디즈니플러스':'20대'}, inplace=True)
ageDF3.rename(columns={'디즈니플러스':'30대'}, inplace=True)
ageDF4.rename(columns={'디즈니플러스':'40대'}, inplace=True)
ageDF5.rename(columns={'디즈니플러스':'50대'}, inplace=True)
ageDF6.rename(columns={'디즈니플러스':'60세이상'}, inplace=True)

# %%
ageallDF = pd.concat([ageDF1,ageDF2,ageDF3,ageDF4,ageDF5,ageDF6], axis=1, join='inner')

# %%
ageallDF = ageallDF.loc[:,~ageallDF.T.duplicated()]

# %%
ageallDF['날짜'] = pd.to_datetime(ageallDF['날짜'])

# %%
ageallDF['Year'] = ageallDF['날짜'].dt.year
ageallDF['Month'] = ageallDF['날짜'].dt.month
ageallDF['Day'] = ageallDF['날짜'].dt.day
ageallDF
# Out:
#              날짜    18세이하      20대      30대      40대      50대    60세이상  Year  \
# 0    2019-01-01  0.03052  0.00747  0.00842  0.00602  0.00000  0.02129  2019
# 1    2019-01-02  0.00000  0.00653  0.00881  0.00376  0.00000  0.00000  2019
# 2    2019-01-03  0.00678  0.01774  0.00612  0.00677  0.00000  0.02129  2019
# 3    2019-01-04  0.00000  0.00933  0.00727  0.00527  0.00454  0.02129  2019
# 4    2019-01-05  0.02035  0.01167  0.00727  0.00903  0.00908  0.00000  2019
# ...         ...      ...      ...      ...      ...      ...      ...   ...
# 1272 2022-06-26  1.90618  1.83722  1.73101  2.62608  3.62447  3.17291  2022
# 1273 2022-06-27  1.36688  1.55428  1.28437  1.94603  3.10214  2.72572  2022
# 1274 2022-06-28  1.30922  1.41982  1.14532  1.75173  3.03856  2.76831  2022
# 1275 2022-06-29  1.55682  1.49825  1.23304  1.99724  2.88413  2.89608  2022
# 1276 2022-06-30  1.80782  1.46604  1.21159  1.91138  3.30653  2.95996  2022
#
#       Month  Day
# 0         1    1
# 1         1    2
# ...

# %%
groupageDF # 연령 월별 그룹화 평균
# Out:
#                 18세이하        20대        30대        40대        50대      60세이상
# Year Month
# 2019 1       0.011265   0.014091   0.012475   0.008182   0.006737   0.005494
#      2       0.012352   0.013035   0.011295   0.008682   0.008108   0.010646
#      3       0.019253   0.029139   0.026536   0.015082   0.014355   0.026101
#      4       0.093269   0.135176   0.098044   0.048370   0.055407   0.066008
#      5       0.164004   0.145485   0.081709   0.041391   0.049516   0.073495
#      6       0.070884   0.077500   0.049460   0.026605   0.033453   0.031228
#      7       0.177353   0.144038   0.093200   0.048584   0.050983   0.072122
#      8       0.189388   0.161058   0.132853   0.083639   0.075010   0.115398
#      9       0.112828   0.136344   0.120746   0.078193   0.074483   0.105757
#      10      0.102404   0.125544   0.123300   0.089153   0.085559   0.149745
#      11      0.450876   0.450717   0.428171   0.368868   0.375765   0.494032
# ...

# %%
recent18DF = groupageDF.iloc[:,0:1]*1960*0.072   # 카테고리 별 건수 계산 20~30대 가장 많음 
recent20DF = groupageDF.iloc[:,1:2]*1960*0.278   # 디즈니 애니가 많지만 생각보다 18세 이하의 관심도가 낮다
recent30DF = groupageDF.iloc[:,2:3]*1960*0.322
recent40DF = groupageDF.iloc[:,3:4]*1960*0.264
recent50DF = groupageDF.iloc[:,4:5]*1960*0.073
recentageDF = pd.concat([recent18DF,recent20DF,recent30DF,recent40DF,recent50DF],axis=1)
recentageDF.plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %% [markdown]
# #### 연령별 건수를 비교했을때 20,30,40대가 가장 많았음
# #### 주력 컨테츠 중 하나인 디즈니가 있음에도 18세 이하의 연령대가 낮은 수치를 보여주고 있고 40대는 높은걸로 보아
# #### 미성년자다 보니 부모님 계정을 이용해 사용하고 있다는 것을 볼 수 있음
# #### 또한, 2021년 11월에 국내서비스 시작으로 많은 관심을 불러오며 급상승 하였으나 넷플릭스에 비해 가격은 저렴하나
# #### 한국 계정에서는 한달 무료나 다양한 프로모션 같은 것이 없고 컨텐츠도 마블, 디즈니에만 집중되었기 때문에
# #### 그래프가 하향선을 그리며 관심도가 점점 떨어져 간다는 것을 볼 수 있음
# #### OTT 서비스가 시작된 후, 극장 개봉되는 마블 작품들을 보기 위해서는 디즈니플러스에서만 제공하는 작품들을 봐야함
# #### 20대를 전후로 한 연령층들의 관심도가 지속적으로 유지될지에 대한 것은 향후 지켜봐야할 것으로 생각됨

# %%
ageallDF_1 = ageallDF.iloc[:,1:-1]
groupageDF = ageallDF_1.groupby(['Year','Month']).mean()

# %%
recentageDF.iloc[:,0:1].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
recentageDF.iloc[:,1:2].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
recentageDF.iloc[:,2:3].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
recentageDF.iloc[:,3:4].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
groupageDF.iloc[:,4:5].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Year,Month'>

# %%
ageallDFsi = ageallDF.set_index('날짜') # 날짜를 index로

# %%
agedf2019 = ageallDF[ageallDF['날짜'].dt.year == 2019]
agedf2020 = ageallDF[ageallDF['날짜'].dt.year == 2020]
agedf2021 = ageallDF[ageallDF['날짜'].dt.year == 2021]
agedf2022 = ageallDF[ageallDF['날짜'].dt.year == 2022]

# %%
agedf2019group = agedf2019.groupby(['Year','Month']).mean()
agedf2020group = agedf2020.groupby(['Year','Month']).mean()
agedf2021group = agedf2021.groupby(['Year','Month']).mean()
agedf2022group = agedf2022.groupby(['Year','Month']).mean()

# %%
ageallDF = ageallDF.drop(labels='Day', axis=1)
ageallDF
# Out:
#              날짜    18세이하      20대      30대      40대      50대    60세이상  Year  \
# 0    2019-01-01  0.03052  0.00747  0.00842  0.00602  0.00000  0.02129  2019
# 1    2019-01-02  0.00000  0.00653  0.00881  0.00376  0.00000  0.00000  2019
# 2    2019-01-03  0.00678  0.01774  0.00612  0.00677  0.00000  0.02129  2019
# 3    2019-01-04  0.00000  0.00933  0.00727  0.00527  0.00454  0.02129  2019
# 4    2019-01-05  0.02035  0.01167  0.00727  0.00903  0.00908  0.00000  2019
# ...         ...      ...      ...      ...      ...      ...      ...   ...
# 1272 2022-06-26  1.90618  1.83722  1.73101  2.62608  3.62447  3.17291  2022
# 1273 2022-06-27  1.36688  1.55428  1.28437  1.94603  3.10214  2.72572  2022
# 1274 2022-06-28  1.30922  1.41982  1.14532  1.75173  3.03856  2.76831  2022
# 1275 2022-06-29  1.55682  1.49825  1.23304  1.99724  2.88413  2.89608  2022
# 1276 2022-06-30  1.80782  1.46604  1.21159  1.91138  3.30653  2.95996  2022
#
#       Month
# 0         1
# 1         1
# 2         1
# ...

# %%
ageallDF
# Out:
#              날짜    18세이하      20대      30대      40대      50대    60세이상  Year  \
# 0    2019-01-01  0.03052  0.00747  0.00842  0.00602  0.00000  0.02129  2019
# 1    2019-01-02  0.00000  0.00653  0.00881  0.00376  0.00000  0.00000  2019
# 2    2019-01-03  0.00678  0.01774  0.00612  0.00677  0.00000  0.02129  2019
# 3    2019-01-04  0.00000  0.00933  0.00727  0.00527  0.00454  0.02129  2019
# 4    2019-01-05  0.02035  0.01167  0.00727  0.00903  0.00908  0.00000  2019
# ...         ...      ...      ...      ...      ...      ...      ...   ...
# 1272 2022-06-26  1.90618  1.83722  1.73101  2.62608  3.62447  3.17291  2022
# 1273 2022-06-27  1.36688  1.55428  1.28437  1.94603  3.10214  2.72572  2022
# 1274 2022-06-28  1.30922  1.41982  1.14532  1.75173  3.03856  2.76831  2022
# 1275 2022-06-29  1.55682  1.49825  1.23304  1.99724  2.88413  2.89608  2022
# 1276 2022-06-30  1.80782  1.46604  1.21159  1.91138  3.30653  2.95996  2022
#
#       Month
# 0         1
# 1         1
# 2         1
# ...

# %%
agedf2022group
# Out:
#                18세이하       20대       30대       40대       50대     60세이상   Day
# Year Month
# 2022 1      4.243665  2.377638  1.951264  3.368600  4.864565  5.388933  16.0
#      2      3.190818  1.877588  1.781489  3.116707  4.568543  4.785984  14.5
#      3      1.846439  1.525258  1.502215  2.737131  3.772740  3.585064  16.0
#      4      1.276211  1.221978  1.066054  1.797238  2.644770  2.645509  15.5
#      5      2.130475  1.662042  1.341160  1.996145  3.092766  2.986065  16.0
#      6      1.548119  1.404454  1.311042  2.192168  3.504257  2.930858  15.5
