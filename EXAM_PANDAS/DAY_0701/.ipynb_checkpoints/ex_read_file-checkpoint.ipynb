# %% [markdown]
# # 다양한 종류의 파일을 DataFrame으로 읽기------
#
# - 메서드 : pandas.read_XXX( '파일경로', 옵션 파라미터...)

# %%
import pandas as pd

# 파일 관련 변수들 선언 ------------------------------------
DIR_PATH ='../../Data/'
FILE_NAME = DIR_PATH+'iris.csv'
FILE_NAME2 = DIR_PATH+'남북한발전전력량.xlsx'

# %%
# CSV 파일 읽기 ===> DataFrame으로 저장----------------------------

irisDF = pd.read_csv(FILE_NAME)

# 데이터 확인 하기
irisDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Name         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# 앞부분 데이터 10개 보여주세요

# %%
# 끝부분 데이터 3개 보여주세요

# %%
# 컬럼의 기술통계 정보 보기
irisDF.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
irisDF.head(10)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
# 5          5.4         3.9          1.7         0.4  Iris-setosa
# 6          4.6         3.4          1.4         0.3  Iris-setosa
# 7          5.0         3.4          1.5         0.2  Iris-setosa
# 8          4.4         2.9          1.4         0.2  Iris-setosa
# 9          4.9         3.1          1.5         0.1  Iris-setosa

# %%
irisDF.tail(3)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
irisDF[irisDF.Name =='Iris-setosa']
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0           5.1         3.5          1.4         0.2  Iris-setosa
# 1           4.9         3.0          1.4         0.2  Iris-setosa
# 2           4.7         3.2          1.3         0.2  Iris-setosa
# 3           4.6         3.1          1.5         0.2  Iris-setosa
# 4           5.0         3.6          1.4         0.2  Iris-setosa
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 6           4.6         3.4          1.4         0.3  Iris-setosa
# 7           5.0         3.4          1.5         0.2  Iris-setosa
# 8           4.4         2.9          1.4         0.2  Iris-setosa
# 9           4.9         3.1          1.5         0.1  Iris-setosa
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# ...

# %%
SL5 = irisDF[irisDF.SepalLength >= 5.0]
SL5[['SepalLength', 'Name']]
# Out:
#      SepalLength            Name
# 0            5.1     Iris-setosa
# 4            5.0     Iris-setosa
# 5            5.4     Iris-setosa
# 7            5.0     Iris-setosa
# 10           5.4     Iris-setosa
# ..           ...             ...
# 145          6.7  Iris-virginica
# 146          6.3  Iris-virginica
# 147          6.5  Iris-virginica
# 148          6.2  Iris-virginica
# 149          5.9  Iris-virginica
#
# [128 rows x 2 columns]

# %%
irisDF.filter(regex='Length')
# Out:
#      SepalLength  PetalLength
# 0            5.1          1.4
# 1            4.9          1.4
# 2            4.7          1.3
# 3            4.6          1.5
# 4            5.0          1.4
# ..           ...          ...
# 145          6.7          5.2
# 146          6.3          5.0
# 147          6.5          5.2
# 148          6.2          5.4
# 149          5.9          5.1
#
# [150 rows x 2 columns]

# %%
#irisDF.max(axis = 1, numeric_only = True) #최대값 구하기
irisDF[irisDF.Name =='Iris-virginnic'].max()  
  #Iris-setosa
# Out:
# SepalLength    NaN
# SepalWidth     NaN
# PetalLength    NaN
# PetalWidth     NaN
# Name           NaN
# dtype: object

# %%
irisDF[irisDF.Name =='Iris-setosa'].min()
# Out:
# SepalLength            4.3
# SepalWidth             2.3
# PetalLength            1.0
# PetalWidth             0.1
# Name           Iris-setosa
# dtype: object

# %%
ElecDF = pd.read_excel(FILE_NAME2)
ElecDF
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
EDF1 = ElecDF.iloc[:,[0]] #[:,::2]
EDF1.fillna(method = 'ffill')
# Out:
#   전력량 (억㎾h)
# 0        남한
# 1        남한
# 2        남한
# 3        남한
# 4        남한
# 5        북한
# 6        북한
# 7        북한
# 8        북한

# %%
addElecDF = ElecDF.fillna(method = 'ffill')
addElecDF['FULLNAME'] = addElecDF['전력량 (억㎾h)'] +" "+ addElecDF['발전 전력별']
s
addElecDF
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2008  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4224
# 1        남한     수력    64    51    49    60    41    55    52    54  ...    56
# 2        남한     화력   484   573   696   803  1022  1122  1264  1420  ...  2658
# 3        남한    원자력   529   563   565   581   587   670   739   771  ...  1510
# 4        남한    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   255
# 6        북한     수력   156   150   142   133   138   142   125   107  ...   141
# 7        북한     화력   121   113   105    88    93    88    88    86  ...   114
# 8        북한    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2009  2010  2011  2012  2013  2014  2015  2016 FULLNAME
# 0  4336  4747  4969  5096  5171  5220  5281  5404    남한 합계
# 1    56    65    78    77    84    78    58    66    남한 수력
# ...

# %%
addElecDF.set_index('FULLNAME')
# Out:
#          전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  \
# FULLNAME
# 남한 합계           남한     합계  1077  1186  1310  1444  1650  1847  2055  2244
# 남한 수력           남한     수력    64    51    49    60    41    55    52    54
# 남한 화력           남한     화력   484   573   696   803  1022  1122  1264  1420
# 남한 원자력          남한    원자력   529   563   565   581   587   670   739   771
# 남한 신재생          남한    신재생     -     -     -     -     -     -     -     -
# 북한 합계           북한     합계   277   263   247   221   231   230   213   193
# 북한 수력           북한     수력   156   150   142   133   138   142   125   107
# 북한 화력           북한     화력   121   113   105    88    93    88    88    86
# 북한 원자력          북한    원자력     -     -     -     -     -     -     -     -
#
#           ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# FULLNAME  ...
# 남한 합계     ...  4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# ...

# %%
addElecDF
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2008  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4224
# 1        남한     수력    64    51    49    60    41    55    52    54  ...    56
# 2        남한     화력   484   573   696   803  1022  1122  1264  1420  ...  2658
# 3        남한    원자력   529   563   565   581   587   670   739   771  ...  1510
# 4        남한    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   255
# 6        북한     수력   156   150   142   133   138   142   125   107  ...   141
# 7        북한     화력   121   113   105    88    93    88    88    86  ...   114
# 8        북한    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2009  2010  2011  2012  2013  2014  2015  2016 FULLNAME
# 0  4336  4747  4969  5096  5171  5220  5281  5404    남한 합계
# 1    56    65    78    77    84    78    58    66    남한 수력
# ...

# %%
ElecDF_1=ElecDF.drop(['전력량 (억㎾h)','발전 전력별'] ,axis=1)
ElecDF_1=ElecDF_1.replace('-', None)
ElecDF_1.max()
ElecDF_1.min()
# Out:
# 1990    64
# 1991    51
# 1992    49
# 1993    60
# 1994    41
# 1995    55
# 1996    52
# 1997    54
# 1998    61
# 1999    61
# 2000    56
# 2001    42
# 2002    53
# 2003    69
# 2004    59
# 2005    52
# 2006    52
# 2007    50
# 2008    56
# 2009    56
# 2010    65
# 2011    78
# 2012    77
# 2013    82
# 2014    78
# 2015    58
# 2016    66
# dtype: object
